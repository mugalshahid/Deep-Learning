# %%
# Introduction to Deep Learning
# (1). ML models ---> works well on less complex data and linear data but 
# DL models ---> works well complex data and non-linear data
# (2). DL models ---> Representative Learning --> input to output result but
# middle process vanish

# DL works on Human Neuron System

# %%
# Architecture of ML Models :
# Data Ingestion ---> data cleaning and preprocessing ---> select ML model based
# on the target ---> model training ---> model accuracy

# %%
# Architecture of DL Models :
# Data Ingestion ---> data cleaning and preprocessing --->
# Model Sequential Layer(
#    input_layer(neurons, activation_function, input_dimension),
#    hidden_layer(neurons, activation_function),
#    output_layer(neurons, activation_function)
# )
#

# %%
# Types of DL Models ::
# (1). ANN(Artifical Neural Networks) ---> used for tabular data
# (2). CNN(Convolutional Neural Networks) ---> for images related data
# (3). RNN(Recurrent Neural Networks) ---> for sequential data

# %%
# Age (x11)
#                  (x21)
# bmi (x12)-                  (x31)  -----> Model compile ---> Model result 
#                  (x22)         output_layer()
#children(x13)         hidden_layer()
#     input_layer()

# %%
# Introduction to Deep Learning :-
# Deep learning is a powerful subset of machine learning that uses multi-layered artificial neural networks
# to learn from vast amounts of data, mimicking the neural structure of the human brain.
# The "deep" in deep learning refers to the presence of multiple hidden layers in the network,
# which allow it to automatically discover and learn complex hierarchical patterns and
# representations within data, such as images, text, and sound, without manual feature extraction.

# %%
# Workflow of Deep Learning
# --Data Ingestion --> Data Cleaning and Preprocessing -->
# Model Sequential Architecture(
#    input_layer(Neurons, Activation_function, input_dimension = df.columns),
#   hidden_layer(Neurons, Activation_function),
 #   output_layer(Neurons(based_on_the_target_column), Activation_function(based_on_the_target_colmun)
#)
# Model.compile(loss_function, otimizer, matrics)
# Model.fit(input_data, target_data)
# Model Prediction, Accuracy, loss

# %%
# Loss Function --> Distance between Actual value and Predicted value
# In term of regression --> MSE, MAE
# In term of classification -->
# case-1 : when we have 2 sub-categories in target column ---> Binarycrossentropy
# case-2 : when we have more than 2 sub-categories in target column --> SparseCategoricalCrossEntropy
# CategoricalCrossEntropy

# %%
# Optimization Technique --> Minimize the loss function

# (1). Gradient Descent :-
# We have a simple line Equation
# y = mx+b ...(1)
# Now, we have to calculate loss function w.r.t m.s.e
# L = 1/n (y_act - y_pred)**2
# n = n(feature) = 1
# L = (y - (mx+b))**2
# L = (y-mx-b)**2 ....(2)
